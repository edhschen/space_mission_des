# %%
from pathlib import Path
import pandas as pd
import altair as alt
alt.data_transformers.enable('data_server')
# Out:
# DataTransformerRegistry.enable('data_server')

# %%
data_dir = Path.cwd().parent.parent / "results" / "test-05"

mc_results = pd.read_csv(data_dir / "mc.csv")
mc_results.head()
# Out:
#    replicant  outcome  duration  anomaly_count  anomaly_time  \
# 0          2    False       4.0              2           4.0
# 1          1    False    3111.0              2        3111.0
# 2          0    False    3116.0              2        3100.0
# 3          3     True    3450.0              0           NaN
# 4          7    False       1.0              2           1.0
#
#      anomaly_vehicle anomaly_activity
# 0  SEP-02 + EOI-MCPS           Ascent
# 1           MOI-MCPS  Lunar Insertion
# 2                HAB        Countdown
# 3                NaN              NaN
# 4  SEP-02 + EOI-MCPS        Countdown

# %%
N = mc_results.replicant.max()
success_rate = sum(mc_results.groupby("replicant").first().outcome) / N
print(f"The success rate was: {success_rate} = {100*success_rate:.3f} %\n")
# Out:
# The success rate was: 0.5735735735735735 = 57.357 %

# %%
replicants = []
rates = []
for i in range(2, N, 1):
    df = mc_results.query(f"replicant <= {i}")
    rate_i = sum(df.groupby("replicant").first().outcome) / (i+1)
    replicants.append(i)
    rates.append(rate_i)

# %%
df = pd.DataFrame({
    "Replicants": replicants,
    "Success Rate": rates
})
df.head(20)
# Out:
#     Replicants  Success Rate
# 0            2      0.000000
# 1            3      0.250000
# 2            4      0.400000
# 3            5      0.500000
# 4            6      0.571429
# 5            7      0.500000
# 6            8      0.444444
# 7            9      0.500000
# 8           10      0.454545
# 9           11      0.500000
# 10          12      0.538462
# 11          13      0.500000
# 12          14      0.533333
# 13          15      0.562500
# 14          16      0.529412
# 15          17      0.500000
# 16          18      0.526316
# 17          19      0.500000
# 18          20      0.476190
# 19          21      0.454545

# %%
alt.Chart(df).mark_line().encode(
    x = alt.X("Replicants", ),
    y = alt.Y("Success Rate", scale=alt.Scale(domain=(0.4, 0.6)))
).properties(
    height = 300,
    width=800
)
# Out:
# alt.Chart(...)
